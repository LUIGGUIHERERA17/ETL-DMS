# %%
import pyodbc
from sqlalchemy import create_engine
import pandas as pd
pyodbc.drivers()
import psycopg2

# %%
user='postgres'
password= 1234
host='localhost'
port='5432'
database='SPRINT_2'
db_url = f'postgresql://{user}:{password}@{host}:{port}/{database}'

# %%
engine = create_engine(db_url)
try:
    conn = engine.connect()
    print('Connection successful')
except Exception as e:
    print('Connection failed')
    print(e)
# Out:
# Connection successful

# %%
query = 'SELECT * FROM test_data.temptabla'
df = pd.read_sql(query, engine)
df
# Out:
#             Order_ID  Order_Date   Ship_Date Customer_ID      Customer_Name  \
# 0     US-2021-130785  2021-09-05  2021-09-09    AG-10900      Arthur Gainer
# 1     US-2020-105249  2020-11-28  2020-11-28    DH-13675      Duane Huffman
# 2     US-2020-123183  2020-11-19  2020-11-25    GR-14560  Georgia Rosenberg
# 3     US-2020-133592  2020-12-31  2021-01-07    KM-16375   Katherine Murray
# 4     US-2022-165848  2022-06-04  2022-06-04    EN-13780      Edward Nazzal
# ...              ...         ...         ...         ...                ...
# 6810  US-2021-121608  2021-09-03  2021-09-05    JB-15400   Jennifer Braxton
# 6811  US-2020-136399  2020-12-16  2020-12-17    CC-12100    Chad Cunningham
# 6812  US-2021-128608  2021-01-12  2021-01-17    CS-12490   Cindy Schnelling
# 6813  US-2020-167199  2020-01-06  2020-01-10    ME-17320      Maria Etezadi
# 6814  US-2022-117590  2022-12-08  2022-12-10    GH-14485          Gene Hale
#
#           Segment Country_Region           City State_Province Postal_Code  \
# 0        Consumer  United States      San Diego     California       92105
# 1     Home Office  United States  San Francisco     California       94122
# 2       Corporate  United States     Wilmington       Delaware       19805
# 3     Home Office  United States     Providence   Rhode Island        2908
# 4        Consumer  United States  New York City       New York       10035
# ...           ...            ...            ...            ...         ...
# 6810    Corporate  United States        Bristol    Connecticut        6010
# 6811  Home Office  United States    Los Angeles     California       90049
# 6812    Corporate  United States         Toledo           Ohio       43615
# 6813  Home Office  United States      Henderson       Kentucky       42420
# 6814    Corporate  United States     Richardson          Texas       75080
#
#        Region            nuevoid    Category Sub_Category  \
# 0        West    FUR-BO-10000330   Furniture    Bookcases
# 1        West  FUR-BO-1000033001   Furniture    Bookcases
# 2        East    FUR-BO-10000362   Furniture    Bookcases
# 3        East  FUR-BO-1000036201   Furniture    Bookcases
# 4        East  FUR-BO-1000036202   Furniture    Bookcases
# ...       ...                ...         ...          ...
# 6810     East  TEC-PH-1000495901  Technology       Phones
# 6811     West    TEC-PH-10004977  Technology       Phones
# 6812     East  TEC-PH-1000497701  Technology       Phones
# 6813    South  TEC-PH-1000497702  Technology       Phones
# 6814  Central  TEC-PH-1000497703  Technology       Phones
#
#                                            Product_Name     Sales  Quantity  \
# 0     Sauder Camden County Barrister Bookcase, Plank...   411.332         4
# 1     Sauder Camden County Barrister Bookcase, Plank...   411.332         4
# 2                    Sauder Inglewood Library Bookcases  1025.880         6
# 3                    Sauder Inglewood Library Bookcases   341.960         2
# 4                    Sauder Inglewood Library Bookcases   136.784         1
# ...                                                 ...       ...       ...
# 6810             Classic Ivory Antique Telephone ZL1810   100.490         1
# 6811                                        GE 30524EE4   627.168         4
# 6812                                        GE 30524EE4   235.188         2
# 6813                                        GE 30524EE4   391.980         2
# 6814                                        GE 30524EE4  1097.544         7
#
#       Discount    Profit
# 0         0.15   -4.8392
# 1         0.15   -4.8392
# 2         0.00  235.9524
# 3         0.00   78.6508
# 4         0.20    5.1294
# ...        ...       ...
# 6810      0.00   25.1225
# 6811      0.20   70.5564
# 6812      0.40  -43.1178
# 6813      0.00  113.6742
# 6814      0.20  123.4737
#
# [6815 rows x 19 columns]
